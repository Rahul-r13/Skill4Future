# %% [markdown]
# # Data Analysis and Visualization of Seattle's Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as dt

# %% [markdown]
# # Loading csv file

# %%
df=pd.read_csv('seattle.csv')

# %%
df
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %%
df.columns
# Out:
# Index(['date', 'precipitation', 'temp_max', 'temp_min', 'wind', 'weather'], dtype='object')

# %%
#changing the datatype
df["date"]=pd.to_datetime(df['date'],format='%Y-%m-%d')

# %%
df["date"]
# Out:
# 0      2012-01-01
# 1      2012-01-02
# 2      2012-01-03
# 3      2012-01-04
# 4      2012-01-05
#           ...
# 1456   2015-12-27
# 1457   2015-12-28
# 1458   2015-12-29
# 1459   2015-12-30
# 1460   2015-12-31
# Name: date, Length: 1461, dtype: datetime64[ns]

# %%
#setting the Date as index
df=df.set_index('date')

# %%
df
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain
# ...                   ...       ...       ...   ...      ...
# 2015-12-27            8.6       4.4       1.7   2.9     rain
# 2015-12-28            1.5       5.0       1.7   1.3     rain
# 2015-12-29            0.0       7.2       0.6   2.6      fog
# 2015-12-30            0.0       5.6      -1.0   3.4      sun
# 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
#creating the moving average for "temp_max" over 30 days
df['temp_max_ma']=df['temp_max'].rolling(window=30).mean()

# %%
#plotting
fig,ax=plt.subplots(figsize=(7,4.5),dpi=300)
ax.plot(df['temp_max'],label="temp_max")
ax.plot(df['temp_max_ma'],label="Moving average of temp max")

#Formatting axe to make it easier to read
ax.xaxis.set_major_locator(dt.YearLocator())
ax.xaxis.set_minor_locator(dt.MonthLocator((1,4,7,10)))

ax.xaxis.set_major_formatter(dt.DateFormatter("\n%Y"))
ax.xaxis.set_minor_formatter(dt.DateFormatter("%b"))
plt.setp(ax.get_xticklabels(), rotation=0, ha="center")
plt.subplots_adjust(bottom=0.15)

#Labelling
plt.xlabel("Date")
plt.ylabel("Temperature (max)")
plt.title("Seattle daily max temperature")
plt.legend()
plt.show()
fig.savefig("output.png")

# %% [markdown]
# Project Summary:
# The project focuses on data analysis and visualization using Python. Required libraries such as `pandas`, `matplotlib`, and `datetime` were imported. A dataset named `seattle.csv` was loaded for analysis. The project involves cleaning and processing the data, followed by exploring trends and patterns. Key insights were derived from the dataset, which include various statistical analyses and visualizations created using Matplotlib. The focus is on presenting meaningful patterns in the data, potentially related to Seattle's environmental or social metrics.

# %% [markdown]
# coded by Rahul R
